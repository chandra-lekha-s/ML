# %%
#Importing necessary Libraries
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
# Reading the dataset
df = pd.read_csv("/content/car_details.csv")````
df2 = dt.copy()
df2.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df2 = df2.drop(['name'],axis = 1)
df2.head()
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2007          60000      70000  Petrol  Individual       Manual
# 1  2007         135000      50000  Petrol  Individual       Manual
# 2  2012         600000     100000  Diesel  Individual       Manual
# 3  2017         250000      46000  Petrol  Individual       Manual
# 4  2014         450000     141000  Diesel  Individual       Manual
#
#           owner
# 0   First Owner
# 1   First Owner
# 2   First Owner
# 3   First Owner
# 4  Second Owner

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

Le = LabelEncoder()
df2['year'] = Le.fit_transform(df2['year'])
df2['fuel'] = Le.fit_transform(df2['fuel'])
df2['seller_type'] = Le.fit_transform(df2['seller_type'])
df2['transmission'] = Le.fit_transform(df2['transmission'])
df2['owner'] = Le.fit_transform(df2['owner'])

# %%
# Reading the dataset
y = df2['transmission']
X = df2.drop(['transmission'],axis=1)

# %%
# split X and y into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)

# %%
#Performing Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Initializing ANN
ann = tf.keras.models.Sequential()
#Adding First Hidden Layer
ann.add(tf.keras.layers.Dense(units=6,activation="relu"))
#Adding Second Hidden Layer
ann.add(tf.keras.layers.Dense(units=6,activation="relu"))

# %%
#Adding Output Layer
ann.add(tf.keras.layers.Dense(units=1,activation="sigmoid"))
#Compiling ANN
ann.compile(optimizer="adam",loss="binary_crossentropy",metrics=['accuracy'])
#Fitting ANN
ann.fit(X_train,y_train,batch_size=32,epochs = 100)
# Saving created neural network
ann.save("ANN.h5")
# Out:
# Epoch 1/100
# 102/102 [==============================] - 1s 2ms/step - loss: 0.5874 - accuracy: 0.8876
# Epoch 2/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4743 - accuracy: 0.9008
# Epoch 3/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.3827 - accuracy: 0.9103
# Epoch 4/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.3071 - accuracy: 0.9177
# Epoch 5/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2596 - accuracy: 0.9232
# Epoch 6/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2362 - accuracy: 0.9247
# Epoch 7/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2267 - accuracy: 0.9229
# Epoch 8/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2225 - accuracy: 0.9232
# Epoch 9/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2198 - accuracy: 0.9223
# Epoch 10/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2180 - accuracy: 0.9238
# Epoch 11/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2168 - accuracy: 0.9232
# Epoch 12/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2153 - accuracy: 0.9238
# Epoch 13/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2145 - accuracy: 0.9232
# Epoch 14/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2133 - accuracy: 0.9232
# Epoch 15/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2121 - accuracy: 0.9247
# Epoch 16/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2111 - accuracy: 0.9244
# Epoch 17/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2101 - accuracy: 0.9244
# Epoch 18/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2094 - accuracy: 0.9278
# Epoch 19/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2087 - accuracy: 0.9263
# Epoch 20/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2080 - accuracy: 0.9260
# Epoch 21/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2071 - accuracy: 0.9266
# Epoch 22/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2066 - accuracy: 0.9275
# Epoch 23/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2056 - accuracy: 0.9278
# Epoch 24/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2052 - accuracy: 0.9269
# Epoch 25/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2048 - accuracy: 0.9275
# Epoch 26/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2039 - accuracy: 0.9269
# Epoch 27/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2035 - accuracy: 0.9278
# Epoch 28/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2030 - accuracy: 0.9275
# Epoch 29/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2026 - accuracy: 0.9284
# Epoch 30/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2018 - accuracy: 0.9281
# Epoch 31/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2016 - accuracy: 0.9287
# Epoch 32/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2012 - accuracy: 0.9284
# Epoch 33/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2007 - accuracy: 0.9287
# Epoch 34/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2005 - accuracy: 0.9281
# Epoch 35/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2003 - accuracy: 0.9284
# Epoch 36/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.2000 - accuracy: 0.9281
# Epoch 37/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1997 - accuracy: 0.9290
# Epoch 38/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1993 - accuracy: 0.9293
# Epoch 39/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1994 - accuracy: 0.9293
# Epoch 40/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1992 - accuracy: 0.9287
# Epoch 41/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1986 - accuracy: 0.9293
# Epoch 42/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1987 - accuracy: 0.9303
# Epoch 43/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1986 - accuracy: 0.9300
# Epoch 44/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1982 - accuracy: 0.9284
# Epoch 45/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1980 - accuracy: 0.9290
# Epoch 46/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1977 - accuracy: 0.9296
# Epoch 47/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1977 - accuracy: 0.9293
# Epoch 48/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1974 - accuracy: 0.9300
# Epoch 49/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1976 - accuracy: 0.9281
# Epoch 50/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1975 - accuracy: 0.9300
# Epoch 51/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1968 - accuracy: 0.9296
# Epoch 52/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1972 - accuracy: 0.9300
# Epoch 53/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1966 - accuracy: 0.9293
# Epoch 54/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1964 - accuracy: 0.9290
# Epoch 55/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1968 - accuracy: 0.9303
# Epoch 56/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1965 - accuracy: 0.9300
# Epoch 57/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1959 - accuracy: 0.9296
# Epoch 58/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1961 - accuracy: 0.9296
# Epoch 59/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1959 - accuracy: 0.9296
# Epoch 60/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1961 - accuracy: 0.9296
# Epoch 61/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1956 - accuracy: 0.9300
# Epoch 62/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1957 - accuracy: 0.9300
# Epoch 63/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1956 - accuracy: 0.9296
# Epoch 64/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1953 - accuracy: 0.9300
# Epoch 65/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1954 - accuracy: 0.9300
# Epoch 66/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1954 - accuracy: 0.9306
# Epoch 67/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1953 - accuracy: 0.9296
# Epoch 68/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1951 - accuracy: 0.9296
# Epoch 69/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1952 - accuracy: 0.9303
# Epoch 70/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1950 - accuracy: 0.9296
# Epoch 71/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1951 - accuracy: 0.9300
# Epoch 72/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1950 - accuracy: 0.9303
# Epoch 73/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1950 - accuracy: 0.9300
# Epoch 74/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1949 - accuracy: 0.9303
# Epoch 75/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1949 - accuracy: 0.9303
# Epoch 76/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1947 - accuracy: 0.9312
# Epoch 77/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1945 - accuracy: 0.9303
# Epoch 78/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1944 - accuracy: 0.9300
# Epoch 79/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1946 - accuracy: 0.9296
# Epoch 80/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1952 - accuracy: 0.9306
# Epoch 81/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1945 - accuracy: 0.9300
# Epoch 82/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1943 - accuracy: 0.9300
# Epoch 83/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1942 - accuracy: 0.9309
# Epoch 84/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1948 - accuracy: 0.9318
# Epoch 85/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1945 - accuracy: 0.9303
# Epoch 86/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1941 - accuracy: 0.9309
# Epoch 87/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1939 - accuracy: 0.9312
# Epoch 88/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1940 - accuracy: 0.9309
# Epoch 89/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1939 - accuracy: 0.9315
# Epoch 90/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1937 - accuracy: 0.9303
# Epoch 91/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1937 - accuracy: 0.9309
# Epoch 92/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1938 - accuracy: 0.9309
# Epoch 93/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1937 - accuracy: 0.9303
# Epoch 94/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1936 - accuracy: 0.9303
# Epoch 95/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1936 - accuracy: 0.9315
# Epoch 96/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1936 - accuracy: 0.9309
# Epoch 97/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1937 - accuracy: 0.9321
# Epoch 98/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1932 - accuracy: 0.9309
# Epoch 99/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1935 - accuracy: 0.9312
# Epoch 100/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1935 - accuracy: 0.9315

# %%
df2.head()
# Out:
#    year  selling_price  km_driven  fuel  seller_type  transmission  owner
# 0    13          60000      70000     4            1             1      0
# 1    13         135000      50000     4            1             1      0
# 2    18         600000     100000     1            1             1      0
# 3    23         250000      46000     4            1             1      0
# 4    20         450000     141000     1            1             1      2

# %%
owner = df2['owner']
seller_type = df2['seller_type']
fuel = df2['fuel']
transmission = df2['transmission']

epochs = range(1, len(owner) + 1)


import matplotlib.pyplot as plt
# "bo" is for "blue dot"
plt.plot(epochs, transmission, 'bo', label='transmission')
# b is for "solid blue line"
plt.plot(epochs, seller_type, 'b', label='seller_type')
plt.title('transmission and seller_type')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
#                           Sample code for ANN

#Importing necessary Libraries
import numpy as np
import pandas as pd
import tensorflow as tf
# Reading the dataset
diabetesdata = pd.read_csv("diabetes.csv")
y = diabetesdata['Outcome']
X = diabetesdata.drop(['Outcome'],axis=1)

# split X and y into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)

#Performing Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
#Initializing ANN
ann = tf.keras.models.Sequential()
#Adding First Hidden Layer
ann.add(tf.keras.layers.Dense(units=6,activation="relu"))
#Adding Second Hidden Layer
ann.add(tf.keras.layers.Dense(units=6,activation="relu"))

#Adding Output Layer
ann.add(tf.keras.layers.Dense(units=1,activation="sigmoid"))
#Compiling ANN
ann.compile(optimizer="adam",loss="binary_crossentropy",metrics=['accuracy'])
#Fitting ANN
ann.fit(X_train,y_train,batch_size=32,epochs = 100)
# Saving created neural network
ann.save("ANN.h5")
